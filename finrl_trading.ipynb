# %% [markdown]
# # Part 1: Data Processing - Stock Trading with Yahoo Finance
#
# Following the NeurIPS 2018 paper structure, this notebook focuses on data download and preprocessing.

# %%
# Install required packages
# !pip install yfinance
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: yfinance in ./venv/lib/python3.12/site-packages (0.2.55)
# Requirement already satisfied: pandas>=1.3.0 in ./venv/lib/python3.12/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in ./venv/lib/python3.12/site-packages (from yfinance) (2.2.4)
# Requirement already satisfied: requests>=2.31 in ./venv/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in ./venv/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in ./venv/lib/python3.12/site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in ./venv/lib/python3.12/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in ./venv/lib/python3.12/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in ./venv/lib/python3.12/site-packages (from yfinance) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./venv/lib/python3.12/site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-cy0957t8
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-cy0957t8
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-cy0957t8
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-cy0957t8
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 69776b349ee4e63efe3826f318aef8e5c5f59648
#   Installing build dependencies ...   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 69776b349ee4e63efe3826f318aef8e5c5f59648
#   Installing build dependencies ... -done
#   Getting requirements to build wheel ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-qsc8amhq/elegantrl_8375e12e08f94168a4ecbaf2e9e4c142
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-qsc8amhq/elegantrl_8375e12e08f94168a4ecbaf2e9e4c142
# done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-qsc8amhq/elegantrl_8375e12e08f94168a4ecbaf2e9e4c142
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-qsc8amhq/elegantrl_8375e12e08f94168a4ecbaf2e9e4c142
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 5e828af1503098f4da046c0f12432dbd4ef8bd97
#   Installing build dependencies ...   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 5e828af1503098f4da046c0f12432dbd4ef8bd97
#   Installing build dependencies ... -done
#   Getting requirements to build wheel ... one
#   Getting requirements to build wheel ... -done
#   Preparing metadata (pyproject.toml) ... one
#   Preparing metadata (pyproject.toml) ... -done
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (3.1.60)
# Requirement already satisfied: jqdatasdk<2,>=1 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pyfolio-reloaded<0.10,>=0.9 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (0.9.8)
# Requirement already satisfied: pyportfolioopt<2,>=1 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.44.1)
# Requirement already satisfied: scikit-learn<2,>=1 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (1.6.1)
# Requirement already satisfied: selenium<5,>=4 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (4.31.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (3.3.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (0.2.55)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.2.4)
# done
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (3.1.60)
# Requirement already satisfied: jqdatasdk<2,>=1 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pyfolio-reloaded<0.10,>=0.9 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (0.9.8)
# Requirement already satisfied: pyportfolioopt<2,>=1 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.44.1)
# Requirement already satisfied: scikit-learn<2,>=1 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (1.6.1)
# Requirement already satisfied: selenium<5,>=4 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (4.31.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (3.3.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in ./venv/lib/python3.12/site-packages (from finrl==0.3.8) (0.2.55)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in ./venv/lib/python3.12/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.2.4)
# Requirement already satisfied: urllib3<2,>1.24 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.11.16)
# Requirement already satisfied: PyYAML==6.0.1 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.12/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (78.1.0)
# Requirement already satisfied: certifi>=2018.1.18 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (2025.1.31)
# Requirement already satisfied: cryptography>=2.6.1 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (44.0.2)
# Requirement already satisfied: aiodns>=1.1.1 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (1.18.3)
# Requirement already satisfied: six in ./venv/lib/python3.12/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.17.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in ./venv/lib/python3.12/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (2.0.40)
# Requirement already satisfied: pymysql>=0.7.6 in ./venv/lib/python3.12/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in ./venv/lib/python3.12/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (0.5.2)
# Requirement already satisfied: ipython>=3.2.3 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (9.0.2)
# Requirement already satisfied: urllib3<2,>1.24 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.11.16)
# Requirement already satisfied: PyYAML==6.0.1 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in ./venv/lib/python3.12/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.12/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (78.1.0)
# Requirement already satisfied: certifi>=2018.1.18 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (2025.1.31)
# Requirement already satisfied: cryptography>=2.6.1 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (44.0.2)
# Requirement already satisfied: aiodns>=1.1.1 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in ./venv/lib/python3.12/site-packages (from ccxt<4,>=3->finrl==0.3.8) (1.18.3)
# Requirement already satisfied: six in ./venv/lib/python3.12/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.17.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in ./venv/lib/python3.12/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (2.0.40)
# Requirement already satisfied: pymysql>=0.7.6 in ./venv/lib/python3.12/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in ./venv/lib/python3.12/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (0.5.2)
# Requirement already satisfied: ipython>=3.2.3 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (9.0.2)
# Requirement already satisfied: matplotlib>=1.4.0 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.10.1)
# Requirement already satisfied: pytz>=2014.10 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2025.2)
# Requirement already satisfied: scipy>=0.14.0 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.15.2)
# Requirement already satisfied: seaborn>=0.7.1 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.13.2)
# Requirement already satisfied: empyrical-reloaded>=0.5.9 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.5.11)
# Requirement already satisfied: cvxpy>=1.1.19 in ./venv/lib/python3.12/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (1.6.4)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in ./venv/lib/python3.12/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in ./venv/lib/python3.12/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (5.24.1)
# Requirement already satisfied: matplotlib>=1.4.0 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.10.1)
# Requirement already satisfied: pytz>=2014.10 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2025.2)
# Requirement already satisfied: scipy>=0.14.0 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.15.2)
# Requirement already satisfied: seaborn>=0.7.1 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.13.2)
# Requirement already satisfied: empyrical-reloaded>=0.5.9 in ./venv/lib/python3.12/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.5.11)
# Requirement already satisfied: cvxpy>=1.1.19 in ./venv/lib/python3.12/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (1.6.4)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in ./venv/lib/python3.12/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in ./venv/lib/python3.12/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (5.24.1)
# Requirement already satisfied: click>=7.0 in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (8.1.8)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.18.0)
# Requirement already satisfied: jsonschema in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (6.30.2)
# Requirement already satisfied: aiosignal in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (1.3.2)
# Requirement already satisfied: frozenlist in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (1.5.0)
# Requirement already satisfied: click>=7.0 in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (8.1.8)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.18.0)
# Requirement already satisfied: jsonschema in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (6.30.2)
# Requirement already satisfied: aiosignal in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (1.3.2)
# Requirement already satisfied: frozenlist in ./venv/lib/python3.12/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (1.5.0)
# Requirement already satisfied: aiohttp_cors in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: colorful in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.5.6)
# Requirement already satisfied: py-spy>=0.4.0 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.71.0)
# Requirement already satisfied: opencensus in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: prometheus_client>=0.7.1 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.21.1)
# Requirement already satisfied: smart_open in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (20.30.0)
# Requirement already satisfied: aiohttp_cors in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: colorful in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.5.6)
# Requirement already satisfied: py-spy>=0.4.0 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.71.0)
# Requirement already satisfied: opencensus in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: prometheus_client>=0.7.1 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.21.1)
# Requirement already satisfied: smart_open in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (20.30.0)
# Requirement already satisfied: tensorboardX>=1.9 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (19.0.1)
# Requirement already satisfied: fsspec in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2025.3.2)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.12/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.12/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (3.6.0)
# Requirement already satisfied: trio~=0.17 in ./venv/lib/python3.12/site-packages (from selenium<5,>=4->finrl==0.3.8) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in ./venv/lib/python3.12/site-packages (from selenium<5,>=4->finrl==0.3.8) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.9 in ./venv/lib/python3.12/site-packages (from selenium<5,>=4->finrl==0.3.8) (4.13.1)
# Requirement already satisfied: tensorboardX>=1.9 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (19.0.1)
# Requirement already satisfied: fsspec in ./venv/lib/python3.12/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2025.3.2)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.12/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.12/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (3.6.0)
# Requirement already satisfied: trio~=0.17 in ./venv/lib/python3.12/site-packages (from selenium<5,>=4->finrl==0.3.8) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in ./venv/lib/python3.12/site-packages (from selenium<5,>=4->finrl==0.3.8) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.9 in ./venv/lib/python3.12/site-packages (from selenium<5,>=4->finrl==0.3.8) (4.13.1)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in ./venv/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in ./venv/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.0)
# Requirement already satisfied: cloudpickle in ./venv/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: opencv-python in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.11.0.86)
# Requirement already satisfied: pygame in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.19.0)
# Requirement already satisfied: psutil in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (7.0.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.67.1)
# Requirement already satisfied: rich in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (14.0.0)
# Requirement already satisfied: ale-py>=0.9.0 in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.10.2)
# Requirement already satisfied: pillow in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.1.0)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.12/site-packages (from webdriver-manager<5,>=4->finrl==0.3.8) (1.1.0)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in ./venv/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in ./venv/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.0)
# Requirement already satisfied: cloudpickle in ./venv/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: opencv-python in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.11.0.86)
# Requirement already satisfied: pygame in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.19.0)
# Requirement already satisfied: psutil in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (7.0.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.67.1)
# Requirement already satisfied: rich in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (14.0.0)
# Requirement already satisfied: ale-py>=0.9.0 in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.10.2)
# Requirement already satisfied: pillow in ./venv/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.1.0)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.12/site-packages (from webdriver-manager<5,>=4->finrl==0.3.8) (1.1.0)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in ./venv/lib/python3.12/site-packages (from wrds<4,>=3->finrl==0.3.8) (2.9.10)
# Requirement already satisfied: multitasking>=0.0.7 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.3.7)
# Requirement already satisfied: frozendict>=2.3.4 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.13.3)
# Requirement already satisfied: th in ./venv/lib/python3.12/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: pycares>=4.0.0 in ./venv/lib/python3.12/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.8) (4.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (0.3.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in ./venv/lib/python3.12/site-packages (from wrds<4,>=3->finrl==0.3.8) (2.9.10)
# Requirement already satisfied: multitasking>=0.0.7 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.3.7)
# Requirement already satisfied: frozendict>=2.3.4 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./venv/lib/python3.12/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.13.3)
# Requirement already satisfied: th in ./venv/lib/python3.12/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: pycares>=4.0.0 in ./venv/lib/python3.12/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.8) (4.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (0.3.1)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.6)
# Requirement already satisfied: cffi>=1.12 in ./venv/lib/python3.12/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in ./venv/lib/python3.12/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: clarabel>=0.5.0 in ./venv/lib/python3.12/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in ./venv/lib/python3.12/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.2.7.post2)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.6)
# Requirement already satisfied: cffi>=1.12 in ./venv/lib/python3.12/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in ./venv/lib/python3.12/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: clarabel>=0.5.0 in ./venv/lib/python3.12/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in ./venv/lib/python3.12/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.2.7.post2)
# Requirement already satisfied: bottleneck>=1.3.0 in ./venv/lib/python3.12/site-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: bottleneck>=1.3.0 in ./venv/lib/python3.12/site-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./venv/lib/python3.12/site-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: decorator in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.19.1)
# Requirement already satisfied: stack_data in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.14.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./venv/lib/python3.12/site-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: decorator in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.19.1)
# Requirement already satisfied: stack_data in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./venv/lib/python3.12/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.12/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas>=1.5.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas>=1.5.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in ./venv/lib/python3.12/site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in ./venv/lib/python3.12/site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.10)
# Requirement already satisfied: greenlet>=1 in ./venv/lib/python3.12/site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in ./venv/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in ./venv/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./venv/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./venv/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.3)
# Requirement already satisfied: Cython>=3.0.10 in ./venv/lib/python3.12/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.0.12)
# Requirement already satisfied: ply<4.0,>=3.4 in ./venv/lib/python3.12/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: greenlet>=1 in ./venv/lib/python3.12/site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in ./venv/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in ./venv/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./venv/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./venv/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.3)
# Requirement already satisfied: Cython>=3.0.10 in ./venv/lib/python3.12/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.0.12)
# Requirement already satisfied: ply<4.0,>=3.4 in ./venv/lib/python3.12/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: networkx in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.4.2)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.13.1)
# Requirement already satisfied: networkx in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.4.2)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: sortedcontainers in ./venv/lib/python3.12/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (2.4.0)
# Requirement already satisfied: outcome in ./venv/lib/python3.12/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in ./venv/lib/python3.12/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in ./venv/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: sortedcontainers in ./venv/lib/python3.12/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (2.4.0)
# Requirement already satisfied: outcome in ./venv/lib/python3.12/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in ./venv/lib/python3.12/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in ./venv/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in ./venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8) (1.7.1)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in ./venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8) (1.7.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in ./venv/lib/python3.12/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.3.9)
# Requirement already satisfied: distlib<1,>=0.3.7 in ./venv/lib/python3.12/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.3.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.12/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.12/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./venv/lib/python3.12/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.24.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./venv/lib/python3.12/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./venv/lib/python3.12/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.24.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.12/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.12/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./venv/lib/python3.12/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.24.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./venv/lib/python3.12/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./venv/lib/python3.12/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.24.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.12/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.12/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: wrapt in ./venv/lib/python3.12/site-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.8) (1.17.2)
# Requirement already satisfied: niltype<2.0,>=0.3 in ./venv/lib/python3.12/site-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.0.2)
# Requirement already satisfied: wrapt in ./venv/lib/python3.12/site-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.8) (1.17.2)
# Requirement already satisfied: niltype<2.0,>=0.3 in ./venv/lib/python3.12/site-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.0.2)
# Requirement already satisfied: pycparser in ./venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.22)
# Requirement already satisfied: pycparser in ./venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.69.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in ./venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.38.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.8.4)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.69.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in ./venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.38.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.13)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in ./venv/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in ./venv/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (0.14.0)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.12/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.12/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.12/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.12/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.12/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.12/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)

# %%
import pandas as pd
import numpy as np
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer
from finrl.config import INDICATORS

# Define parameters
TRAIN_START_DATE = '2009-01-01'  # Following NeurIPS 2018 paper timeframe
TRAIN_END_DATE = '2019-01-01'
TEST_START_DATE = '2019-01-01'
TEST_END_DATE = '2021-01-01'

# Define stock symbols (you can modify this list)
TICKER_LIST = ['AAPL', 'MSFT', 'JPM', 'BA', 'GE', 'T']

def process_data(start_date, end_date):
    """Download and process data for a given date range"""
    print(f"Downloading data from {start_date} to {end_date}...")
    df = YahooDownloader(
        start_date=start_date,
        end_date=end_date,
        ticker_list=TICKER_LIST
    ).fetch_data()
    
    print("Processing features...")
    fe = FeatureEngineer(
        use_technical_indicator=True,
        tech_indicator_list=INDICATORS,
        use_turbulence=True
    )
    
    processed = fe.preprocess_data(df)
    return processed

# Process training data
train_data = process_data(TRAIN_START_DATE, TRAIN_END_DATE)
print("\nTraining data shape:", train_data.shape)

# Process testing data
test_data = process_data(TEST_START_DATE, TEST_END_DATE)
print("Testing data shape:", test_data.shape)

# Save processed data
train_data.to_csv('train.csv', index=False)
test_data.to_csv('trade.csv', index=False)

print("\nData has been processed and saved to train.csv and trade.csv")

# Display sample of processed data
print("\nSample of processed training data:")
print(train_data.head())

# Display feature information
print("\nFeatures included:")
print(train_data.columns.tolist())
# Out:
# Downloading data from 2009-01-01 to 2019-01-01...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (15096, 8)
# Processing features...
# Successfully added technical indicators
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Successfully added turbulence index
#
# Training data shape: (15096, 17)
# Downloading data from 2019-01-01 to 2021-01-01...
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3030, 8)
# Processing features...
# Successfully added technical indicators
# Successfully added technical indicators
# Successfully added turbulence index
# Testing data shape: (3030, 17)
# Successfully added turbulence index
# Testing data shape: (3030, 17)
#
# Data has been processed and saved to train.csv and trade.csv
#
# Sample of processed training data:
#          date      close       high        low       open     volume   tic  \
# 0  2009-01-02   2.730994   3.251429   3.041429   3.067143  746015200  AAPL
# 1  2009-01-02  33.941101  45.560001  42.779999  42.799999    7010200    BA
# 2  2009-01-02  56.576836  81.806908  77.972954  79.123138   11917130    GE
# 3  2009-01-02  20.973110  31.639999  30.469999  31.190001   32494900   JPM
# 4  2009-01-02  14.924775  20.400000  19.370001  19.530001   50084000  MSFT
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0    4   0.0  2.951623  2.625623   100.0  66.666667  100.0      2.730994
# 1    4   0.0  2.951623  2.625623   100.0  66.666667  100.0     33.941101
# 2    4   0.0  2.951623  2.625623   100.0  66.666667  100.0     56.576836
# 3    4   0.0  2.951623  2.625623   100.0  66.666667  100.0     20.973110
# 4    4   0.0  2.951623  2.625623   100.0  66.666667  100.0     14.924775
#
#    close_60_sma  turbulence
# 0      2.730994         0.0
# 1     33.941101         0.0
# 2     56.576836         0.0
# 3     20.973110         0.0
# 4     14.924775         0.0
#
# Features included:
# ['date', 'close', 'high', 'low', 'open', 'volume', 'tic', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma', 'turbulence']
#
# Data has been processed and saved to train.csv and trade.csv
#
# Sample of processed training data:
#          date      close       high        low       open     volume   tic  \
# 0  2009-01-02   2.730994   3.251429   3.041429   3.067143  746015200  AAPL
# 1  2009-01-02  33.941101  45.560001  42.779999  42.799999    7010200    BA
# 2  2009-01-02  56.576836  81.806908  77.972954  79.123138   11917130    GE
# 3  2009-01-02  20.973110  31.639999  30.469999  31.190001   32494900   JPM
# 4  2009-01-02  14.924775  20.400000  19.370001  19.530001   50084000  MSFT
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0    4   0.0  2.951623  2.625623   100.0  66.666667  100.0      2.730994
# 1    4   0.0  2.951623  2.625623   100.0  66.666667  100.0     33.941101
# 2    4   0.0  2.951623  2.625623   100.0  66.666667  100.0     56.576836
# 3    4   0.0  2.951623  2.625623   100.0  66.666667  100.0     20.973110
# 4    4   0.0  2.951623  2.625623   100.0  66.666667  100.0     14.924775
#
#    close_60_sma  turbulence
# 0      2.730994         0.0
# 1     33.941101         0.0
# 2     56.576836         0.0
# 3     20.973110         0.0
# 4     14.924775         0.0
#
# Features included:
# ['date', 'close', 'high', 'low', 'open', 'volume', 'tic', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma', 'turbulence']

# %% [markdown]
# # Part 2: Model Training
#
# This section implements the training process following the NeurIPS 2018 paper approach.

# %%
from finrl.meta.env_stock_trading.env_stocktrading_np import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent

# Load the preprocessed training data
train_data = pd.read_csv('train.csv')

# Set up environment parameters
stock_dimension = len(train_data.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension

# Convert data to arrays for training
price_array = train_data[['close']].values
tech_array = train_data[INDICATORS].values
turbulence_array = train_data['turbulence'].values

# Environment configuration
env_config = {
    "price_array": price_array,
    "tech_array": tech_array,
    "turbulence_array": turbulence_array,
    "if_train": True,
    "initial_amount": 1000000,  # $1M initial capital
    "buy_cost_pct": 0.001,    # 0.1% trading cost
    "sell_cost_pct": 0.001,   # 0.1% trading cost
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# Create training environment
env_train = StockTradingEnv(config=env_config)

# Initialize DRL agent
agent = DRLAgent(env=env_train)

# PPO model parameters following NeurIPS 2018
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128
}

# Get and train the model
model_ppo = agent.get_model("ppo", model_kwargs=PPO_PARAMS)

# Train the model
trained_ppo = agent.train_model(
    model=model_ppo,
    tb_log_name="ppo_train",
    total_timesteps=100000  # Increase for better performance
)

# Save the trained model
trained_ppo.save("trained_ppo_model")
print("Model training completed and saved as 'trained_ppo_model'")
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/group3/venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ----------------------------------
# | time/              |           |
# |    fps             | 1437      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 2.6158385 |
# ----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1258         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0044814735 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.000857     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 21.8         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00327     |
# |    reward               | -0.71569985  |
# |    std                  | 0.997        |
# |    value_loss           | 41.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1258         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0044814735 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.000857     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 21.8         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00327     |
# |    reward               | -0.71569985  |
# |    std                  | 0.997        |
# |    value_loss           | 41.6         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1208          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00047141418 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0112        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 11.2          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000138     |
# |    reward               | 0.09999065    |
# |    std                  | 0.996         |
# |    value_loss           | 28.5          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1208          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00047141418 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0112        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 11.2          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000138     |
# |    reward               | 0.09999065    |
# |    std                  | 0.996         |
# |    value_loss           | 28.5          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1187         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0014532546 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0288       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 36.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000442    |
# |    reward               | -2.777773    |
# |    std                  | 1            |
# |    value_loss           | 61.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1187         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0014532546 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0288       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 36.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000442    |
# |    reward               | -2.777773    |
# |    std                  | 1            |
# |    value_loss           | 61.2         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1172          |
# |    iterations           | 5             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00023409637 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.063         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 22.5          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000253     |
# |    reward               | -0.20394951   |
# |    std                  | 1             |
# |    value_loss           | 54.2          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1172          |
# |    iterations           | 5             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00023409637 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.063         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 22.5          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000253     |
# |    reward               | -0.20394951   |
# |    std                  | 1             |
# |    value_loss           | 54.2          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1163         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0040776236 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16           |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000971    |
# |    reward               | 14.377894    |
# |    std                  | 1            |
# |    value_loss           | 36.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1163         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0040776236 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16           |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000971    |
# |    reward               | 14.377894    |
# |    std                  | 1            |
# |    value_loss           | 36.9         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1157          |
# |    iterations           | 7             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 4.2691827e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0424        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 624           |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -4e-06        |
# |    reward               | -298.92596    |
# |    std                  | 1             |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1157          |
# |    iterations           | 7             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 4.2691827e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0424        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 624           |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -4e-06        |
# |    reward               | -298.92596    |
# |    std                  | 1             |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 1152          |
# |    iterations           | 8             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00012500153 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0493        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.88e+03      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -5.7e-05      |
# |    reward               | -0.41819957   |
# |    std                  | 1             |
# |    value_loss           | 3.77e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 1152          |
# |    iterations           | 8             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00012500153 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0493        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.88e+03      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -5.7e-05      |
# |    reward               | -0.41819957   |
# |    std                  | 1             |
# |    value_loss           | 3.77e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 1150          |
# |    iterations           | 9             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 3.8613565e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.099         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 540           |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -2.19e-05     |
# |    reward               | 6.3392777     |
# |    std                  | 1             |
# |    value_loss           | 2.2e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 1150          |
# |    iterations           | 9             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 3.8613565e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.099         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 540           |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -2.19e-05     |
# |    reward               | 6.3392777     |
# |    std                  | 1             |
# |    value_loss           | 2.2e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 1148         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 5.850452e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.6         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 1.59e-05     |
# |    reward               | -11.761177   |
# |    std                  | 1            |
# |    value_loss           | 38.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 1148         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 5.850452e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.6         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 1.59e-05     |
# |    reward               | -11.761177   |
# |    std                  | 1            |
# |    value_loss           | 38.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 1147         |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0008202689 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000255    |
# |    reward               | -16.951628   |
# |    std                  | 1            |
# |    value_loss           | 44.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 1147         |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0008202689 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000255    |
# |    reward               | -16.951628   |
# |    std                  | 1            |
# |    value_loss           | 44.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+04    |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 12          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 7.04187e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 156         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -4.05e-05   |
# |    reward               | 25.727467   |
# |    std                  | 1           |
# |    value_loss           | 334         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+04    |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 12          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 7.04187e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 156         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -4.05e-05   |
# |    reward               | 25.727467   |
# |    std                  | 1           |
# |    value_loss           | 334         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 1146          |
# |    iterations           | 13            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.7268758e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.351         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 406           |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -3.13e-05     |
# |    reward               | -4.0580807    |
# |    std                  | 1             |
# |    value_loss           | 978           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 231           |
# | time/                   |               |
# |    fps                  | 1146          |
# |    iterations           | 13            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.7268758e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.351         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 406           |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -3.13e-05     |
# |    reward               | -4.0580807    |
# |    std                  | 1             |
# |    value_loss           | 978           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 1144         |
# |    iterations           | 14           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0059127947 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 39.3         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00271     |
# |    reward               | 0.0          |
# |    std                  | 1            |
# |    value_loss           | 106          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 1144         |
# |    iterations           | 14           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0059127947 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 39.3         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00271     |
# |    reward               | 0.0          |
# |    std                  | 1            |
# |    value_loss           | 106          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 54.4          |
# | time/                   |               |
# |    fps                  | 1143          |
# |    iterations           | 15            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.0958291e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.478         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 61.2          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -1.9e-05      |
# |    reward               | 1.7934555     |
# |    std                  | 1             |
# |    value_loss           | 161           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 54.4          |
# | time/                   |               |
# |    fps                  | 1143          |
# |    iterations           | 15            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.0958291e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.478         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 61.2          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -1.9e-05      |
# |    reward               | 1.7934555     |
# |    std                  | 1             |
# |    value_loss           | 161           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 1142         |
# |    iterations           | 16           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0010782899 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 205          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00029     |
# |    reward               | -2.646824    |
# |    std                  | 1            |
# |    value_loss           | 287          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 1142         |
# |    iterations           | 16           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0010782899 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 205          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00029     |
# |    reward               | -2.646824    |
# |    std                  | 1            |
# |    value_loss           | 287          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+04    |
# |    ep_rew_mean          | 54.4        |
# | time/                   |             |
# |    fps                  | 1141        |
# |    iterations           | 17          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008467058 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00578    |
# |    reward               | 2.3719723   |
# |    std                  | 0.997       |
# |    value_loss           | 34.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+04    |
# |    ep_rew_mean          | 54.4        |
# | time/                   |             |
# |    fps                  | 1141        |
# |    iterations           | 17          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008467058 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00578    |
# |    reward               | 2.3719723   |
# |    std                  | 0.997       |
# |    value_loss           | 34.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 1140         |
# |    iterations           | 18           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 3.853973e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0674       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 347          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -6.11e-05    |
# |    reward               | 8.392661     |
# |    std                  | 0.997        |
# |    value_loss           | 744          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 1140         |
# |    iterations           | 18           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 3.853973e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0674       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 347          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -6.11e-05    |
# |    reward               | 8.392661     |
# |    std                  | 0.997        |
# |    value_loss           | 744          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 1139         |
# |    iterations           | 19           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0007551202 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 133          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -1.63e-05    |
# |    reward               | -16.587713   |
# |    std                  | 0.997        |
# |    value_loss           | 262          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 1139         |
# |    iterations           | 19           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0007551202 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 133          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -1.63e-05    |
# |    reward               | -16.587713   |
# |    std                  | 0.997        |
# |    value_loss           | 262          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 54.4          |
# | time/                   |               |
# |    fps                  | 1138          |
# |    iterations           | 20            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.7384213e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.205         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.71e+03      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -2.89e-05     |
# |    reward               | 12.274399     |
# |    std                  | 0.997         |
# |    value_loss           | 4.49e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 54.4          |
# | time/                   |               |
# |    fps                  | 1138          |
# |    iterations           | 20            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.7384213e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.205         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.71e+03      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -2.89e-05     |
# |    reward               | 12.274399     |
# |    std                  | 0.997         |
# |    value_loss           | 4.49e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 1138         |
# |    iterations           | 21           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 5.097309e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.33e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -5.79e-05    |
# |    reward               | -250.75919   |
# |    std                  | 0.997        |
# |    value_loss           | 6.29e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 1138         |
# |    iterations           | 21           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 5.097309e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.33e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -5.79e-05    |
# |    reward               | -250.75919   |
# |    std                  | 0.997        |
# |    value_loss           | 6.29e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 54.4          |
# | time/                   |               |
# |    fps                  | 1137          |
# |    iterations           | 22            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00013197702 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.25          |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.24e+03      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00014      |
# |    reward               | 2.7540593     |
# |    std                  | 0.996         |
# |    value_loss           | 1.33e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | 54.4          |
# | time/                   |               |
# |    fps                  | 1137          |
# |    iterations           | 22            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00013197702 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.25          |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.24e+03      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00014      |
# |    reward               | 2.7540593     |
# |    std                  | 0.996         |
# |    value_loss           | 1.33e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -98.3        |
# | time/                   |              |
# |    fps                  | 1137         |
# |    iterations           | 23           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0001914753 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.2e+03      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000357    |
# |    reward               | 113.44533    |
# |    std                  | 0.996        |
# |    value_loss           | 5.92e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -98.3        |
# | time/                   |              |
# |    fps                  | 1137         |
# |    iterations           | 23           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0001914753 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.2e+03      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000357    |
# |    reward               | 113.44533    |
# |    std                  | 0.996        |
# |    value_loss           | 5.92e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -98.3        |
# | time/                   |              |
# |    fps                  | 1136         |
# |    iterations           | 24           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 9.439129e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 610          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000101    |
# |    reward               | -214.5016    |
# |    std                  | 0.996        |
# |    value_loss           | 888          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -98.3        |
# | time/                   |              |
# |    fps                  | 1136         |
# |    iterations           | 24           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 9.439129e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 610          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000101    |
# |    reward               | -214.5016    |
# |    std                  | 0.996        |
# |    value_loss           | 888          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -98.3        |
# | time/                   |              |
# |    fps                  | 1135         |
# |    iterations           | 25           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 3.407392e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.22e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000187    |
# |    reward               | -61.801083   |
# |    std                  | 0.996        |
# |    value_loss           | 6.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -98.3        |
# | time/                   |              |
# |    fps                  | 1135         |
# |    iterations           | 25           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 3.407392e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.22e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000187    |
# |    reward               | -61.801083   |
# |    std                  | 0.996        |
# |    value_loss           | 6.02e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | -98.3         |
# | time/                   |               |
# |    fps                  | 1135          |
# |    iterations           | 26            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 6.3019164e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.245         |
# ...
# |    value_loss           | 2.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -194         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 42           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 9.730668e-05 |
# |    clip_fraction        | 0.00581      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.42e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000273     |
# |    reward               | -76.613075   |
# |    std                  | 0.994        |
# |    value_loss           | 5.31e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -194         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 42           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 9.730668e-05 |
# |    clip_fraction        | 0.00581      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.42e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000273     |
# |    reward               | -76.613075   |
# |    std                  | 0.994        |
# |    value_loss           | 5.31e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -194         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 43           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 1.532439e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.374        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.74e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 7.16e-05     |
# |    reward               | 267.20612    |
# |    std                  | 0.994        |
# |    value_loss           | 3.93e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -194         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 43           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 1.532439e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.374        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.74e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 7.16e-05     |
# |    reward               | 267.20612    |
# |    std                  | 0.994        |
# |    value_loss           | 3.93e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+04   |
# |    ep_rew_mean          | -194       |
# | time/                   |            |
# |    fps                  | 1132       |
# |    iterations           | 44         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00296982 |
# |    clip_fraction        | 0.0113     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.52       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.98e+03   |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.000754  |
# |    reward               | 122.091965 |
# |    std                  | 0.991      |
# |    value_loss           | 4.84e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+04   |
# |    ep_rew_mean          | -194       |
# | time/                   |            |
# |    fps                  | 1132       |
# |    iterations           | 44         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00296982 |
# |    clip_fraction        | 0.0113     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.52       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.98e+03   |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.000754  |
# |    reward               | 122.091965 |
# |    std                  | 0.991      |
# |    value_loss           | 4.84e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 45           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0016895265 |
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.99e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000953    |
# |    reward               | -1.1678295   |
# |    std                  | 0.989        |
# |    value_loss           | 4.7e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 45           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0016895265 |
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.99e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000953    |
# |    reward               | -1.1678295   |
# |    std                  | 0.989        |
# |    value_loss           | 4.7e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 46           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0011803661 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.223        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.67e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000528    |
# |    reward               | 22.866488    |
# |    std                  | 0.991        |
# |    value_loss           | 2.27e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 46           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0011803661 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.223        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.67e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000528    |
# |    reward               | 22.866488    |
# |    std                  | 0.991        |
# |    value_loss           | 2.27e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 47           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0002168057 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0531       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 767          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000216    |
# |    reward               | -18.181583   |
# |    std                  | 0.991        |
# |    value_loss           | 2.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 47           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0002168057 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0531       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 767          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000216    |
# |    reward               | -18.181583   |
# |    std                  | 0.991        |
# |    value_loss           | 2.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 48           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0035856436 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 445          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00132     |
# |    reward               | 14.999927    |
# |    std                  | 0.989        |
# |    value_loss           | 899          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+04     |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 48           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0035856436 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 445          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00132     |
# |    reward               | 14.999927    |
# |    std                  | 0.989        |
# |    value_loss           | 899          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | -154          |
# | time/                   |               |
# |    fps                  | 1132          |
# |    iterations           | 49            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00020075968 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.769         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 738           |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000194     |
# |    reward               | -17.551573    |
# |    std                  | 0.99          |
# |    value_loss           | 1.42e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.51e+04      |
# |    ep_rew_mean          | -154          |
# | time/                   |               |
# |    fps                  | 1132          |
# |    iterations           | 49            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00020075968 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.769         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 738           |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000194     |
# |    reward               | -17.551573    |
# |    std                  | 0.99          |
# |    value_loss           | 1.42e+03      |
# -------------------------------------------
# Model training completed and saved as 'trained_ppo_model'
# Model training completed and saved as 'trained_ppo_model'

# %% [markdown]
# ## Model Evaluation
#
# Test the trained model on the test dataset

# %%
# Load test data
test_data = pd.read_csv('trade.csv')

# Prepare test data arrays
price_array_test = test_data[['close']].values
tech_array_test = test_data[INDICATORS].values
turbulence_array_test = test_data['turbulence'].values

# Configure test environment
env_config_test = env_config.copy()
env_config_test.update({
    "price_array": price_array_test,
    "tech_array": tech_array_test,
    "turbulence_array": turbulence_array_test,
    "if_train": False
})

env_test = StockTradingEnv(config=env_config_test)

# Run test episodes
state = env_test.reset()
done = False
episode_returns = []

try:
    while not done:
        # Convert state to numpy array if it's not already
        if isinstance(state, tuple):
            state = state[0]  # Get the first element if it's a tuple
        state_array = np.array(state)
        
        # Ensure state is 2D array with shape (1, state_dim)
        if state_array.ndim == 1:
            state_array = state_array.reshape(1, -1)
            
        # Get action from model
        action, _ = trained_ppo.predict(state_array)
        
        # Execute action in environment
        step_result = env_test.step(action)
        
        # Handle different step() return formats
        if len(step_result) == 4:
            next_state, reward, done, info = step_result
        elif len(step_result) == 5:
            next_state, reward, terminated, truncated, info = step_result
            done = terminated or truncated
        else:
            raise ValueError(f"Unexpected step() return format with {len(step_result)} values")
            
        state = next_state
        episode_returns.append(float(reward))  # Convert reward to float
        
except Exception as e:
    print(f"An error occurred during evaluation: {str(e)}")
    print(f"Error type: {type(e)}")
    done = True

# Print results
print(f"\nEvaluation Results:")
if episode_returns:
    total_return = sum(episode_returns)
    print(f"Test Episode Return: {float(total_return):.2f}")  # Convert to float before formatting
    print(f"Initial Portfolio Value: ${env_config_test['initial_amount']:,.2f}")
    try:
        print(f"Final Portfolio Value: ${float(env_test.portfolio_value):,.2f}")  # Convert to float
    except Exception as e:
        print(f"Could not get final portfolio value: {str(e)}")
# Out:
# Evaluation Results:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 61
#      59 print(f"\nEvaluation Results:")
#      60 if episode_returns:
# ---> 61     print(f"Test Episode Return: {sum(episode_returns):.2f}")
#      62     print(f"Initial Portfolio Value: ${env_config_test['initial_amount']:,.2f}")
#      63     try:
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__
